# %% [markdown]
# <a href="https://colab.research.google.com/github/DuarteVn/image-recognition/blob/main/image_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Definição do problema

# %% [markdown]
# *   Input (x): imagens
# *   Output(y): texto retirado das imagems com acurácia > 80%

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Etapa 1: Importação de bibliotecas

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
tf.__version__
# Out:
# '2.18.0'

# %%
dataset_path = '/content/drive/MyDrive/Colab Notebooks/Excel/captcha_images/'

# %%
# Exemplo de visualização de imagem
sample_image = os.listdir(dataset_path)[0]
image = cv2.imread(os.path.join(dataset_path, sample_image))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.title(f'Arquivo: {sample_image}')
plt.axis('off')
plt.show()
